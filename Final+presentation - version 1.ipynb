# %% [markdown]
# # We know the magical formula to plant a highly-rated hotel in NYC.

# %% [markdown]
# ## Key issue: how to increase our overal rating ?

# %% [markdown]
# Some questinos we want to explore:

# %% [markdown]
# ### 1. Contributing factors to high rating

# %%
from IPython.display import Image
Image(filename='1.png')

# %% [markdown]
# ### 2. Location

# %% [markdown]
# It is suggsted to build the new branch in the Midtown East district in NYC.

# %%
from IPython.display import Image
Image(filename='2.png')

# %% [markdown]
# ### 3. Brand affiliation

# %%
from IPython.display import Image
Image(filename='3.png')

# %% [markdown]
# ### 4.Positioning

# %%
from IPython.display import Image
Image(filename='4.png')

# %% [markdown]
# ### 5. Price range

# %%
from IPython.display import Image
Image(filename='5.png')

# %% [markdown]
# ### 6. Online Marketing

# %%
from IPython.display import Image
Image(filename='6.png')

# %% [markdown]
# # Thanks!
